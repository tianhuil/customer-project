# %%
import matplotlib.pylab as plt
import pandas as pd

plt.style.use('seaborn')

# %% [markdown]
# # Customer Data
#
# Load customer data and plot tenure

# %%
df = pd.read_csv("./data.csv")
df.shape
# Out:
# (7043, 21)

# %%
ax=df['tenure'].hist(bins=72, alpha=.6, density=True, cumulative=True)
ax.set_title('User Churn')
ax.set_xlabel('months');
